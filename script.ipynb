# %%
import pandas as pd  
df = pd.read_excel("Files/Maestro de trabajadores cierre septiembre.xlsx", skiprows=3)  
#dirty_data = df[['Nomre y apellidos', 'CI', 'Unidad']]
df = df['Unidad'].value_counts()
#df.head(10)
print(df)
# unidades = []
# for index, fila in dirty_data.iterrows():
#     persona = {
#         'nombre': fila['Nomre y apellidos'],
#         'ci': fila['CI'], 
#         'unidad': fila['Unidad']
#     }
#     unidades.append(persona)

# print(f"Total de registros: {len(unidades)}")
# print(unidades[:5])
# Out:
# Unidad
# Administración Complejo     46
# UEB Producción y Empaque    43
# Tienda Habana               39
# Almacén Distribuidor        28
# Servicientro Trinidad       27
#                             ..
# Ferretería La Lonja          1
# PV Coopelia                  1
# PV Olivos I                  1
# PAC Pesca Tunaz              1
# PV Emifar                    1
# Name: count, Length: 115, dtype: int64
